# %% [markdown]
# # Football Tracking Pipeline
#
# ## Usage
# 1. Upload videos to `input_videos/`
# 2. Run all cells
# 3. Outputs appear in `output_videos/`
#
# ## Notes
# - Requires trained model in `models/`
# - ROIs must exist or be generated

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install ultralytics opencv-python matplotlib numpy
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 36.7 MB/s eta 0:00:00
# ...

# %%
# !rm -rf /content/drive/MyDrive/FootballTracking

# %%
# !mkdir -p /content/drive/MyDrive/FootballTracking
# !unzip -oq /content/drive/MyDrive/football-tracking-colab.zip -d /content/drive/MyDrive/FootballTracking

# %%
import sys
sys.path.append('/content/drive/MyDrive/FootballTracking')

# %%
# !pip install supervision
from football_tracking.config import PipelineConfig
from football_tracking.pipeline import process_new_videos
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.9/41.9 kB 2.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 217.4/217.4 kB 12.3 MB/s eta 0:00:00
# ...
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
config = PipelineConfig(
    project_root="/content/drive/MyDrive/FootballTracking",
    input_dir="/content/drive/MyDrive/FootballTracking/input_videos",
    output_dir="/content/drive/MyDrive/FootballTracking/output_videos",
    roi_dir="/content/drive/MyDrive/FootballTracking/rois",
    model_path="/content/drive/MyDrive/FootballTracking/models/best.pt",
    processed_manifest_path="/content/drive/MyDrive/FootballTracking/manifests/processed_videos.json",
	  has_kickoff = True,
	  team_attack_directions = {"vest_team": "right", "other_team": "left"},
    stubs_dir = "/content/drive/MyDrive/FootballTracking/stubs",

)

# %%
import logging
import sys

logging.basicConfig(
    level=logging.INFO,
    format="%(asctime)s [%(levelname)s] %(message)s",
    handlers=[logging.StreamHandler(sys.stdout)],
    force=True,
)

logging.info("Logging is configured")
# Out:
# 2026-04-09 10:31:36,294 [INFO] Logging is configured

# %%
process_new_videos(config)
# Out:
# 2026-04-09 14:06:05,931 [INFO] Found 1 new videos
# 2026-04-09 14:06:05,932 [INFO] Processing video: /content/drive/MyDrive/FootballTracking/input_videos/DJI_20260329191610_0003_D.mp4
# 2026-04-09 14:06:08,071 [INFO] Video metadata: {'fps': 50.0, 'frame_count': 137112, 'width': 2688, 'height': 1512}
# 2026-04-09 14:06:12,758 [INFO] Step 1 Load Frames done in 6.8s
# 2026-04-09 14:06:13,161 [INFO] Step 2 ROI handling done in 0.4s
# ...
# 2026-04-09 14:06:13,639 [INFO] Initialized YOLOv8n tracker
# 2026-04-09 16:35:34,722 [INFO] Assigned teams to player tracks
# 2026-04-09 16:35:35,669 [INFO] Smoothed player team assignments
# 2026-04-09 16:35:35,670 [INFO] Step 3 Player tracking and team assignment done in 4372.3s
# 2026-04-09 16:35:39,191 [INFO] Tracking progress: 0/137112 frames (0.0%)
# 2026-04-09 16:37:13,206 [INFO] Tracking progress: 3000/137112 frames (2.2%)
# 2026-04-09 16:39:22,342 [INFO] Tracking progress: 7000/137112 frames (5.1%)
# ...
